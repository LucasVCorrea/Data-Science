# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
#df_category_links = pd.read_csv("/content/categorylinks.csv") # PUEDE SER 
#df_contents = pd.read_csv("/content/contents.csv")  # PUEDE SER 
df_logs = pd.read_csv("/content/drive/MyDrive/Organizacion De Datos/Trabajo_practico/logs.csv")  # TIENE QUE SER ESTE
#df_contents_text_sample = pd.read_csv("/content/contents_text_sample.csv") # NO ABRE
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <ipython-input-1-50be734ebb28>:6: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_logs = pd.read_csv("/content/drive/MyDrive/Organizacion De Datos/Trabajo_practico/logs.csv")  # TIENE QUE SER ESTE

# %%
#df_logs.head()

# %%
#df_logs.info()

# %%
df_logs_limpio = df_logs # copio para evitar el warning del .loc      
df_logs_limpio
# Out:
#            item_id             timestamp contributor_username  contributor_id  \
# 0                1  2004-12-23T07:10:09Z               Sabbut          2075.0
# 1                2  2004-12-23T07:14:09Z               Sabbut          2075.0
# 2                3  2004-12-23T07:26:10Z               Sabbut          2075.0
# 3                4  2004-12-23T07:55:09Z               Sanbec          7856.0
# 4                5  2004-12-23T08:02:22Z               Sanbec          7856.0
# ...            ...                   ...                  ...             ...
# 12188941  15587395  2021-09-03T03:09:13Z              SeroBOT       4980693.0
# 12188942  15587396  2021-09-03T03:09:48Z          Leonpolanco        561850.0
# 12188943  15587397  2021-09-03T03:09:49Z            Desiretjs       6335019.0
# 12188944  15587398  2021-09-03T03:10:33Z            Correogsk        443260.0
# 12188945  15587399  2021-09-03T03:10:38Z           Liza.amane       6335020.0
#
#          contributor_ip                                            comment  \
# 0                   NaN  el contenido era: 'Si aprendés Pensamiento Cie...
# 1                   NaN  el contenido era: '{{destruir}}en algun lugar ...
# 2                   NaN            el contenido era: '#REDIRECT [[Flash]]'
# 3                   NaN  Sin información de origen ni de licencia. Hay ...
# 4                   NaN  Sustituida por  [[commons:Image:Heckert_GNU.png]]
# ...                 ...                                                ...
# 12188941            NaN  Aviso de pruebas a usuario tras reversiones co...
# 12188942            NaN  Página creada con «{{subst:Aviso prueba2|Luis ...
# 12188943            NaN                                                NaN
# 12188944            NaN                 Página redirigida a [[Contenedor]]
# 12188945            NaN                                                NaN
#
#            logtype  action                                              title
# 0           delete  delete                                   Verificacionismo
# 1           delete  delete                                           Rapunzel
# 2           delete  delete                                   Macromedia Flash
# 3           delete  delete                               Archivo:Gnu head.png
# 4           delete  delete                            Archivo:Gnu-head-sm.jpg
# ...            ...     ...                                                ...
# 12188941    create  create                     Usuario discusión:El guachicol
# 12188942    create  create  Usuario discusión:2806:2F0:3140:BE0:C09B:D1C4:...
# 12188943  newusers  create                                  Usuario:Desiretjs
# 12188944    create  create                                       Contenedores
# 12188945  newusers  create                                 Usuario:Liza.amane
#
# [12188946 rows x 9 columns]

# %%
df_logs_limpio["timestamp"] = pd.to_datetime(df_logs_limpio["timestamp"]).dt.date # paso la fecha a objeto fecha con datetime y dt.date para que me saque la hora
df_logs_limpio
# Out:
#            item_id   timestamp contributor_username  contributor_id  \
# 0                1  2004-12-23               Sabbut          2075.0
# 1                2  2004-12-23               Sabbut          2075.0
# 2                3  2004-12-23               Sabbut          2075.0
# 3                4  2004-12-23               Sanbec          7856.0
# 4                5  2004-12-23               Sanbec          7856.0
# ...            ...         ...                  ...             ...
# 12188941  15587395  2021-09-03              SeroBOT       4980693.0
# 12188942  15587396  2021-09-03          Leonpolanco        561850.0
# 12188943  15587397  2021-09-03            Desiretjs       6335019.0
# 12188944  15587398  2021-09-03            Correogsk        443260.0
# 12188945  15587399  2021-09-03           Liza.amane       6335020.0
#
#          contributor_ip                                            comment  \
# 0                   NaN  el contenido era: 'Si aprendés Pensamiento Cie...
# 1                   NaN  el contenido era: '{{destruir}}en algun lugar ...
# 2                   NaN            el contenido era: '#REDIRECT [[Flash]]'
# 3                   NaN  Sin información de origen ni de licencia. Hay ...
# 4                   NaN  Sustituida por  [[commons:Image:Heckert_GNU.png]]
# ...                 ...                                                ...
# 12188941            NaN  Aviso de pruebas a usuario tras reversiones co...
# 12188942            NaN  Página creada con «{{subst:Aviso prueba2|Luis ...
# 12188943            NaN                                                NaN
# 12188944            NaN                 Página redirigida a [[Contenedor]]
# 12188945            NaN                                                NaN
#
#            logtype  action                                              title
# 0           delete  delete                                   Verificacionismo
# 1           delete  delete                                           Rapunzel
# 2           delete  delete                                   Macromedia Flash
# 3           delete  delete                               Archivo:Gnu head.png
# 4           delete  delete                            Archivo:Gnu-head-sm.jpg
# ...            ...     ...                                                ...
# 12188941    create  create                     Usuario discusión:El guachicol
# 12188942    create  create  Usuario discusión:2806:2F0:3140:BE0:C09B:D1C4:...
# 12188943  newusers  create                                  Usuario:Desiretjs
# 12188944    create  create                                       Contenedores
# 12188945  newusers  create                                 Usuario:Liza.amane
#
# [12188946 rows x 9 columns]

# %%
df_logs_limpio["actividades"] = 0   # agrego la columna actividades, para que tenga la cantidad que hubo
df_logs_limpio
# Out:
#            item_id   timestamp contributor_username  contributor_id  \
# 0                1  2004-12-23               Sabbut          2075.0
# 1                2  2004-12-23               Sabbut          2075.0
# 2                3  2004-12-23               Sabbut          2075.0
# 3                4  2004-12-23               Sanbec          7856.0
# 4                5  2004-12-23               Sanbec          7856.0
# ...            ...         ...                  ...             ...
# 12188941  15587395  2021-09-03              SeroBOT       4980693.0
# 12188942  15587396  2021-09-03          Leonpolanco        561850.0
# 12188943  15587397  2021-09-03            Desiretjs       6335019.0
# 12188944  15587398  2021-09-03            Correogsk        443260.0
# 12188945  15587399  2021-09-03           Liza.amane       6335020.0
#
#          contributor_ip                                            comment  \
# 0                   NaN  el contenido era: 'Si aprendés Pensamiento Cie...
# 1                   NaN  el contenido era: '{{destruir}}en algun lugar ...
# 2                   NaN            el contenido era: '#REDIRECT [[Flash]]'
# 3                   NaN  Sin información de origen ni de licencia. Hay ...
# 4                   NaN  Sustituida por  [[commons:Image:Heckert_GNU.png]]
# ...                 ...                                                ...
# 12188941            NaN  Aviso de pruebas a usuario tras reversiones co...
# 12188942            NaN  Página creada con «{{subst:Aviso prueba2|Luis ...
# 12188943            NaN                                                NaN
# 12188944            NaN                 Página redirigida a [[Contenedor]]
# 12188945            NaN                                                NaN
#
#            logtype  action                                              title  \
# 0           delete  delete                                   Verificacionismo
# 1           delete  delete                                           Rapunzel
# 2           delete  delete                                   Macromedia Flash
# 3           delete  delete                               Archivo:Gnu head.png
# 4           delete  delete                            Archivo:Gnu-head-sm.jpg
# ...            ...     ...                                                ...
# 12188941    create  create                     Usuario discusión:El guachicol
# 12188942    create  create  Usuario discusión:2806:2F0:3140:BE0:C09B:D1C4:...
# 12188943  newusers  create                                  Usuario:Desiretjs
# 12188944    create  create                                       Contenedores
# 12188945  newusers  create                                 Usuario:Liza.amane
#
#           actividades
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 12188941            0
# 12188942            0
# 12188943            0
# 12188944            0
# 12188945            0
#
# [12188946 rows x 10 columns]

# %%
df_logs_limpio = df_logs_limpio[ ["timestamp","actividades"] ]  # me quedo con los datos que me interesan
df_logs_limpio
# Out:
#            timestamp  actividades
# 0         2004-12-23            0
# 1         2004-12-23            0
# 2         2004-12-23            0
# 3         2004-12-23            0
# 4         2004-12-23            0
# ...              ...          ...
# 12188941  2021-09-03            0
# 12188942  2021-09-03            0
# 12188943  2021-09-03            0
# 12188944  2021-09-03            0
# 12188945  2021-09-03            0
#
# [12188946 rows x 2 columns]

# %%
agrupado_fechas = df_logs_limpio.groupby("timestamp").count()
agrupado_fechas = agrupado_fechas.reset_index()

# %%
# filtrar con loc para ver que no se repita el maximo y el minimo
maxima_cantidad = agrupado_fechas.actividades.max()
minima_cantidad = agrupado_fechas.actividades.min()

agrupado_fechas["maximo"] = agrupado_fechas["actividades"] >= maxima_cantidad
agrupado_fechas["minimo"] = agrupado_fechas["actividades"] <= minima_cantidad
agrupado_fechas.head()

# %%
agrupado_fechas[agrupado_fechas["maximo"] == True ]

# %%
agrupado_fechas[agrupado_fechas["minimo"] == True ]

# %%
cant_actividad_minima = agrupado_fechas.actividades.min()
cant_actividad_maxima = agrupado_fechas.actividades.max()
maximo_dia = (agrupado_fechas[ agrupado_fechas['actividades'] == cant_actividad_maxima]).index[0] # no esta conceptualmente bien
minimo_dia = (agrupado_fechas[ agrupado_fechas['actividades'] == cant_actividad_minima]).index[0] # ""  ""  ""

# %%
print("1) Dia con más actividad:   {}   ({} acciones totales)".format(maximo_dia, cant_actividad_maxima))
print("2) Dia con menos actividad: {}   ({} acciones totales)".format(minimo_dia, cant_actividad_minima))
# Out:
# 1) Dia con más actividad:   3769   (390863 acciones totales)
# 2) Dia con menos actividad: 61   (4 acciones totales)
